# %% [markdown]
#   VARIABLES

# %% [markdown]
# Int & Float

# %%
900/7
# Out:
# 128.57142857142858

# %%
10-100
# Out:
# -90

# %% [markdown]
# 5*5*5*5*5*5*5

# %%
age = 50

# %% [markdown]
# age yazdığımız yerde 50'yi bul getir

# %% [markdown]
# DATA TYPE

# %% [markdown]
# eğer kullanırken type(variable) şeklinde yazarak çalıştırırsak bize variable 'ın türünü verir.

# %% [markdown]
# İSİMLENDİRMELER

# %% [markdown]
# camelCase
#
#
# snake_case

# %% [markdown]
# Matematikteki işlem önceliğine biz belirtmeden kendi dikkat eder
#
#
# Parantezlere almakla uğraşmak zorunda değiliz

# %%
2 - 10 * 2
# Out:
# -18

# %% [markdown]
# Üssü işlemini belirtmek için
#
#
# 2 ** 5 kulanıyoruz
#
# bunu 2 üssü 5 olarak okuyor

# %%
2 ** 9
# Out:
# 512

# %% [markdown]
# String

# %%
"hello world"
# Out:
# 'hello world'

# %%
print("hello python")
# Out:
# hello python

# %%
name = "Elif"

# %%
type(name)
# Out:
# str

# %%
name = "elif"

# %%
name.capitalize()
# Out:
# 'Elif'

# %%
help(name.count)
# Out:
# Help on built-in function count:
#
# count(sub[, start[, end]], /) method of builtins.str instance
#     Return the number of non-overlapping occurrences of substring sub in string S[start:end].
#
#     Optional arguments start and end are interpreted as in slice notation.

# %% [markdown]
# help ile bilmediğimiz, anlamadığımız kısımlar hakkında bilgi alabiliriz

# %%
name.count("e")
# Out:
# 1

# %%
name.upper()
# Out:
# 'ELIF'

# %%
name
# Out:
# 'elif'

# %%
nameUpper = name.upper()

# %%
nameUpper
# Out:
# 'ELIF'

# %%
len(name)
# Out:
# 4

# %% [markdown]
# len eğer arada boşluk varsa onu da sayar kaç karakter olduğunu verir

# %%
myName = "james hetfield"

# %%
myName[len(myName)-1]
# Out:
# 'd'

# %%
myName[-1]
# Out:
# 'd'

# %% [markdown]
# Uzun uzun yazmak yerine direkt -1'le de amacımıza ulaşabiliyoruz.
#
# Bu Python'a özel bir durumdur.

# %%
#key-value pairing

# %%
fitness_dictionary = {"banana":100 , "apple":150}

# %%
type(fitness_dictionary)
# Out:
# dict

# %% [markdown]
# liste veya dizideki gibi bir index mantığı yoktur
#
# Sadece anahtar ve değer eşleşmeleri vardır

# %% [markdown]
# banana ve apple anahtar 100 ve 150 değer

# %%
fitness_dictionary["banana"]
# Out:
# 100

# %%
fitness_dictionary["apple"]
# Out:
# 150

# %% [markdown]
# 100 veya 150 yazsam anahtarı alamazdım

# %% [markdown]
# -------------------------------------------------------------------------------------------------

# %% [markdown]
# ÖZELLİKLERİ

# %%
fitness_dictionary.keys()
# Out:
# dict_keys(['banana', 'apple'])

# %% [markdown]
# sadece anahtarları aldı

# %%
fitness_dictionary.values()
# Out:
# dict_values([100, 150])

# %% [markdown]
# sadece değerleri aldı

# %% [markdown]
# --------------------------------------

# %% [markdown]
# Bir örnek olarak eğer değerleri buradan ayrı olarak bir listeye almak isteseydik:

# %%
list(fitness_dictionary.values())
# Out:
# [100, 150]

# %% [markdown]
# -------------------------------------------------------------------------------------------------

# %% [markdown]
# değeri değiştirmek istersek :

# %%
fitness_dictionary["banana"] = 200

# %%
fitness_dictionary
# Out:
# {'banana': 200, 'apple': 150}

# %% [markdown]
# -------------------------------------------------------------------------------------------------

# %% [markdown]
# yeni bir amahtar eklemek istersek :

# %%
fitness_dictionary["melon"] = 300

# %%
fitness_dictionary
# Out:
# {'banana': 200, 'apple': 150, 'melon': 300}

# %% [markdown]
# -------------------------------------------------------------------------------------------------

# %% [markdown]
# GET

# %% [markdown]
# Uygulama içinde hata mesajı almamak için eğer aradığımız anahtar bulunamıyorsa hata yerine default bir değer döndürmesi için kullanırız.

# %%
fitness_dictionary.get("apple",0)
# Out:
# 150

# %%
fitness_dictionary.get("appl",0)
# Out:
# 0

# %% [markdown]
# eğer apple varsa değerini getir yoksa 0 döndür (vardı 150 geldi)

# %% [markdown]
# eğer appl varsa değerini getiryoksa 0 döndür(yoktu 0 geldi)

# %% [markdown]
# -------------------------------------------------------------------------------------------------

# %% [markdown]
# dictionary içindeki anahtar ve değerlerin veri tipleri birbirinden farklı olabilir

# %%
last_dictionary = {"k1":10,"k2":[10,20,30,40,50],"k3":"string","k4":{"a":100,"b":200}}

# %%
last_dictionary["k2"][2]
# Out:
# 30

# %%
last_dictionary["k4"]["b"]
# Out:
# 200

# %% [markdown]
# Lists

# %% [markdown]
# İçinde birden fazla veri tutan bir veri yapısıdır.

# %%
myString = " Hello World "

# %%
myString.split()
# Out:
# ['Hello', 'World']

# %%
type(myString.split())
# Out:
# list

# %% [markdown]
# Split, sınırlandırılmış bir dizeyi alt dizelere bölmek için kullanılır. Sıfır veya daha fazla sınırlayıcı karakter veya dize belirtmek için karakter dizisi veya dize dizisi kullanabilirsiniz. Sınırlayıcı karakter belirtilmezse, dize boşluk karakterlerine bölünür.

# %% [markdown]
# Immutable - Immutability (Değiştirilemezlik)

# %% [markdown]
# string objelerinde sadece bir tane değeri , bir indexi değiştiremeyiz. Komple baştan hepsini değiştireceksek değiştirebiliyoruz

# %% [markdown]
# LIST

# %% [markdown]
# bu özellik yoktur. İstediğimiz gibi değiştirebiliriz.

# %%
x = 10
y = 20
z = 30

# %%
myList = [x,y,z]

# %%
myList
# Out:
# [10, 20, 30]

# %% [markdown]
# Veri tutarken bir sürü değişken tanımlamak yerine liste içinde tutabiliyoruz

# %%
type(myList)
# Out:
# list

# %%
type(myList[0])
# Out:
# int

# %%
myList[0] = 100

# %%
myList[0]
# Out:
# 100

# %% [markdown]
# Mutable - Mutabilitiy

# %% [markdown]
# Stringlerin aksine indexleri ayrı ayrı değiştirilebiliyor

# %%
len(myList)
# Out:
# 3

# %%
myList[-1]
# Out:
# 30

# %% [markdown]
# pythona özel bir özellik olarak -1 dediğimizde listenin sonundaki elemanı veriyor.

# %% [markdown]
# ---Liste Özellikleri---

# %% [markdown]
# Liste'ye Eklemek

# %% [markdown]
# Append

# %%
myList.append(80)

# %%
myList
# Out:
# [100, 20, 30, 80]

# %% [markdown]
# Listenin sonuna eklemek istediğimiz sayıyı (80) ekledi

# %% [markdown]
# list.append --> Listenin sonuna ekler
#
# list.clear --> listeyi temizler (Her şeyi siler)
#
# list.copy --> listeyi kopyalar
#
# list.count --> aradığımız değerden liste içinde kaç tane olduğunu sayar
#
# list.extend --> başka bir listeye ekleyip eklenti gibi uzatabiliyor
#
# list.index --> aradığımız değerin kaçıncı indexte olduğunu belirtir
#
# list.append --> append'ten farklı olarak hem neyi eklemek istediğimizi hem de nereye eklemek istediğimizi alarak ekleme yapar
#
# list.pop --> son elemana atar
#
# list.remove --> hangi elemanı çıkarmak istiyosak onu listeden çıkartır
#
# list.reverse --> listeyi tersine çevirir
#
# list.sort --> Listeyi küçükten büyüğe ya da alfabetik olarak dizer

# %% [markdown]
# ----Kullanıcıdan Girdi Alma----

# %% [markdown]
# input ile alınan her şey string olarak alınır

# %%
x = input("enter x")
# Out:
# enter x  20

# %%
x
# Out:
# ' 20'

# %%
type(x)
# Out:
# str

# %%
inputList = []

# %%
inputList.append(x)

# %% [markdown]
# string olarak aldığı için direkt olarak burada çarpma vs matematiksel bir işlem yapamam

# %% [markdown]
# ---Veri Tipi Dönüştürme---

# %% [markdown]
# int to string
#
# int(myString)
#
# string to int
#
# str(myIneteger)
#
# string to float
#
# float(myString)
#
#
# Eğer değerimiz sayı değil de harf olsaydı stringimizi int ve floata direkt çeviremeyecektik. Hata verirdi

# %% [markdown]
# list1 + list2 dersek iki listeyi arka arkaya birleştirerek yeni bir list oluşturur

# %% [markdown]
# list1*2 dersek list1'i yan yana iki kere koyarak yeni bir liste oluşturur

# %% [markdown]
# ----MixedList----

# %%
mixedList = ["Elif" , 100 , 3.14]

# %%
mixedList
# Out:
# ['Elif', 100, 3.14]

# %% [markdown]
# Farklı veri tiplerinden değerleri listede bir arada tutabilir ve hepsinin ayrı ayrı bakıldığında veri tiplerini bilir.
#
# Ancak bunu kullanarak bir şey yapmak istiyorsak her verinin veri tipini ayrı ayrı alarak bir işlem yapmalıyız

# %%
type(mixedList[0])
# Out:
# str

# %%
type(mixedList[1])
# Out:
# int

# %%
type(mixedList[2])
# Out:
# float

# %% [markdown]
# ----NestedList----

# %% [markdown]
# İç içe geçmiş listelerdir.

# %%
myNestedList = [10, 20, 3.14, "elif" , [1,2,3]]

# %%
myNestedList[0]
# Out:
# 10

# %%
myNestedList[1]
# Out:
# 20

# %%
myNestedList[2]
# Out:
# 3.14

# %%
myNestedList[3]
# Out:
# 'elif'

# %%
myNestedList[4]
# Out:
# [1, 2, 3]

# %% [raw]
# Stringlerde slicing işlemleri geçerlidir.

# %% [markdown]
# SLICING

# %%
names = " Elif Berra"

# %%
surName = "Çelik "

# %%
fullName = names + " " + surName

# %%
fullName
# Out:
# ' Elif Berra Çelik '

# %%
fullName * 5
# Out:
# ' Elif Berra Çelik  Elif Berra Çelik  Elif Berra Çelik  Elif Berra Çelik  Elif Berra Çelik '

# %% [markdown]
# slicing --> starting index, stopping index, stepping size

# %%
barcode = "ABCDE123456789"

# %%
barcode
# Out:
# 'ABCDE123456789'

# %%
barcode [ : : ]
# Out:
# 'ABCDE123456789'

# %% [markdown]
# barcode[ starting index : stopping index : stepping size ]

# %%
barcode [3 : : ]
# Out:
# 'DE123456789'

# %%
barcode [ :3 : ]
# Out:
# 'ABC'

# %%
barcode [::2]
# Out:
# 'ACE2468'

# %%
barcode[3:5:]
# Out:
# 'DE'

# %%
barcode[::-1]
# Out:
# '987654321EDCBA'

# %% [markdown]
# stepping size -1 olursa stringii tersten yazar bu da python'a özel bir durumdur.

# %% [markdown]
# starting index yazılan sayıyı dahil eder , stopping index etmez
